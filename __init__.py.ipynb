# %%
from .layers import PositionalEmbedding, MultiheadAttention
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1082790266.py in <cell line: 0>()
#       3 from tensorflow.keras.layers import Layer, Embedding
#       4
# ----> 5 class PositionalEmbedding(Layer):
#       6     def __init__(self, input_dim, output_dim, max_len=LAG, **kwargs):
#       7         super().__init__(**kwargs)
#
# /tmp/ipython-input-1082790266.py in PositionalEmbedding()
#       4
#       5 class PositionalEmbedding(Layer):
# ----> 6     def __init__(self, input_dim, output_dim, max_len=LAG, **kwargs):
#       7         super().__init__(**kwargs)
#       8         self.input_dim = input_dim
#
# NameError: name 'LAG' is not defined
